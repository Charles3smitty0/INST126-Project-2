# %%
# You must use upper case letters 

import random

# Asking the name of the user

user = input("Please enter your name. \n")


print("Welcome to hangman" + user , "!")

words = ["WFIDSPQZ", "XHO' 'TTDBFRT", "QQJYF", "ENQD", "DNPK", "CNTR", "EHWHOD", "TSVMOHOF", "XNOCFQGTM"]

# This function radomly chooses one of the words
word = random.choice(words)

print("Guess the characters")

guesses = ''

turns = 10


while turns > 0:
  
   failed = 0
   # all characters from the input word taking one at a time.
   for char in word:
       # comparing that character with the character in guesses
       if char in guesses:
           print(char)
       else:
           print("_")
           # for every failure 1 will be incremented in failure
           failed += 1
          

   if failed == 0:
       print("You Win")
      
       # print correct word
       print("The word is: ", word)
       break
  
   
   guess = input("guess a character:")
  
   # the inputs are stored here
   guesses += guess

   if guess not in word:
      
       turns -= 1
       print("Wrong")
      
       # number of turns that the user has left
       print("You have ", + turns, ' more guesses')

      
       if turns == 0:
           print("\nYou Loose")
           print("The word is:", word)


        
shift = 3 

cipher_text = input("Please enter word ")

plain_text = ""

for c in encrypted_text:

    # upper or lowercase
    if c.isupper():

        #  0-25
        c_unicode = ord(c)

        c_index = ord(c) - ord("A")

        # negative shift
        new_index = (c_index - shift) % 26

        # convert to new character
        new_unicode = new_index + ord("A")

        new_character = chr(new_unicode)

        plain_text = plain_text + new_character

    else:

        # leave lowercase letters
        plain_text += c

print("Encrypted text:",cipher_text)

print("Decrypted text:",plain_text)
# Out:
# Please enter your name.
# hh
# Welcome to hangmanhh !
# Guess the characters
# _
# _
# _
# _
# _
# _
# _
# _
# _
# guess a character:T
# _
# _
# _
# _
# _
# _
# _
# T
# _
# guess a character:X
# X
# _
# _
# _
# _
# _
# _
# T
# _
# guess a character:N
# X
# N
# _
# _
# _
# _
# _
# T
# _
# guess a character:O
# X
# N
# O
# _
# _
# _
# _
# T
# _
# guess a character:C
# X
# N
# O
# C
# _
# _
# _
# T
# _
# guess a character:F
# X
# N
# O
# C
# F
# _
# _
# T
# _
# guess a character:Q
# X
# N
# O
# C
# F
# Q
# _
# T
# _
# guess a character:G
# X
# N
# O
# C
# F
# Q
# G
# T
# _
# guess a character:M
# X
# N
# O
# C
# F
# Q
# G
# T
# M
# You Win
# The word is:  XNOCFQGTM
# Please enter word XNOCFQGTM
# Encrypted text: XNOCFQGTM
# Decrypted text: NNGVC
